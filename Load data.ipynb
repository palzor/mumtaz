# %% [markdown]
# Import the framework library first

# %%
import mumtaz as mt

# %%
dbutils.widgets.text('ADFPipelineName',"None")
pipelineName=dbutils.widgets.get("ADFPipelineName")

# %%
MDF=mt.DBFrameworkHelper(None if pipelineName == "None" else pipelineName)

# %%
MDF.execute_load_data()

# %%
# %sql
show databases

# %%
# %sql
use metadata;
show tables

# %%
# %sql
use bronze_salesltreporting;
show tables

# %%
# %sql
select * from bronze_SalesLTReporting.raw_Address

# %%
# %sql
select * from bronze_SalesLTReporting.raw_Customer
